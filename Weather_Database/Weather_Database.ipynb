# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from citipy import citipy
from config import OpenWeather_API_KEY
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime
import requests

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 748

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + OpenWeather_API_KEY

# %%
# city_url = url + "&q=" + city.replace(" ","+")
# local_weather = requests.get(city_url).json()
# # local_weather["weather"][0]['description']
# local_weather

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
#         city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
#                           "Date": city_date,
                          "Current Description": city_current_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | aden
# Processing Record 2 of Set 1 | punta arenas
# Processing Record 3 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | manicore
# Processing Record 6 of Set 1 | bethel
# Processing Record 7 of Set 1 | hilo
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | teya
# Processing Record 10 of Set 1 | cabra
# Processing Record 11 of Set 1 | longyearbyen
# Processing Record 12 of Set 1 | chinhoyi
# Processing Record 13 of Set 1 | busselton
# Processing Record 14 of Set 1 | montescaglioso
# Processing Record 15 of Set 1 | tuktoyaktuk
# Processing Record 16 of Set 1 | yulara
# Processing Record 17 of Set 1 | guatire
# Processing Record 18 of Set 1 | khani
# Processing Record 19 of Set 1 | kodiak
# Processing Record 20 of Set 1 | astipalaia
# City not found. Skipping...
# Processing Record 21 of Set 1 | new norfolk
# Processing Record 22 of Set 1 | mar del plata
# Processing Record 23 of Set 1 | paradwip
# City not found. Skipping...
# Processing Record 24 of Set 1 | gilgit
# Processing Record 25 of Set 1 | iquitos
# Processing Record 26 of Set 1 | dondo
# Processing Record 27 of Set 1 | vila
# Processing Record 28 of Set 1 | kahului
# Processing Record 29 of Set 1 | zheleznodorozhnyy
# Processing Record 30 of Set 1 | albany
# Processing Record 31 of Set 1 | codrington
# Processing Record 32 of Set 1 | motema
# Processing Record 33 of Set 1 | buala
# Processing Record 34 of Set 1 | barrow
# Processing Record 35 of Set 1 | kuliyapitiya
# Processing Record 36 of Set 1 | avarua
# Processing Record 37 of Set 1 | pangnirtung
# Processing Record 38 of Set 1 | lahaina
# Processing Record 39 of Set 1 | cherskiy
# Processing Record 40 of Set 1 | arraial do cabo
# Processing Record 41 of Set 1 | plettenberg bay
# Processing Record 42 of Set 1 | basco
# Processing Record 43 of Set 1 | san cristobal
# Processing Record 44 of Set 1 | faanui
# Processing Record 45 of Set 1 | saint-philippe
# Processing Record 46 of Set 1 | fort saint james
# Processing Record 47 of Set 1 | cape town
# Processing Record 48 of Set 1 | grand gaube
# Processing Record 49 of Set 1 | sorong
# Processing Record 50 of Set 1 | kapaa
# Processing Record 1 of Set 2 | salalah
# Processing Record 2 of Set 2 | provideniya
# Processing Record 3 of Set 2 | kribi
# Processing Record 4 of Set 2 | beloha
# Processing Record 5 of Set 2 | luderitz
# Processing Record 6 of Set 2 | kulhudhuffushi
# Processing Record 7 of Set 2 | mataura
# Processing Record 8 of Set 2 | perama
# Processing Record 9 of Set 2 | jiayuguan
# Processing Record 10 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 11 of Set 2 | necochea
# Processing Record 12 of Set 2 | den helder
# Processing Record 13 of Set 2 | sungairaya
# Processing Record 14 of Set 2 | ilulissat
# Processing Record 15 of Set 2 | carnarvon
# Processing Record 16 of Set 2 | santo tomas
# Processing Record 17 of Set 2 | diofior
# Processing Record 18 of Set 2 | leshukonskoye
# Processing Record 19 of Set 2 | thunder bay
# Processing Record 20 of Set 2 | byron bay
# Processing Record 21 of Set 2 | taltal
# Processing Record 22 of Set 2 | ngunguru
# Processing Record 23 of Set 2 | puerto escondido
# Processing Record 24 of Set 2 | alamosa
# Processing Record 25 of Set 2 | serowe
# Processing Record 26 of Set 2 | tiksi
# Processing Record 27 of Set 2 | bluff
# Processing Record 28 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 29 of Set 2 | butaritari
# Processing Record 30 of Set 2 | adre
# Processing Record 31 of Set 2 | flinders
# Processing Record 32 of Set 2 | dumai
# Processing Record 33 of Set 2 | mahebourg
# Processing Record 34 of Set 2 | east london
# Processing Record 35 of Set 2 | muros
# Processing Record 36 of Set 2 | cabo san lucas
# Processing Record 37 of Set 2 | north bend
# Processing Record 38 of Set 2 | puerto carreno
# Processing Record 39 of Set 2 | katsuura
# Processing Record 40 of Set 2 | torbay
# Processing Record 41 of Set 2 | kaitangata
# Processing Record 42 of Set 2 | olga
# Processing Record 43 of Set 2 | port alfred
# Processing Record 44 of Set 2 | coquimbo
# Processing Record 45 of Set 2 | jalu
# Processing Record 46 of Set 2 | vaini
# Processing Record 47 of Set 2 | jamestown
# Processing Record 48 of Set 2 | dikson
# Processing Record 49 of Set 2 | xinqing
# Processing Record 50 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 1 of Set 3 | chumikan
# Processing Record 2 of Set 3 | shubarkuduk
# Processing Record 3 of Set 3 | victoria
# Processing Record 4 of Set 3 | saskylakh
# Processing Record 5 of Set 3 | lompoc
# Processing Record 6 of Set 3 | wanaka
# Processing Record 7 of Set 3 | asuncion
# Processing Record 8 of Set 3 | pombia
# Processing Record 9 of Set 3 | naica
# Processing Record 10 of Set 3 | sao joao da barra
# Processing Record 11 of Set 3 | hermanus
# Processing Record 12 of Set 3 | tual
# Processing Record 13 of Set 3 | ushuaia
# Processing Record 14 of Set 3 | marsaxlokk
# Processing Record 15 of Set 3 | clyde river
# Processing Record 16 of Set 3 | xunchang
# Processing Record 17 of Set 3 | mangrol
# Processing Record 18 of Set 3 | tshela
# Processing Record 19 of Set 3 | sibolga
# Processing Record 20 of Set 3 | oranjemund
# Processing Record 21 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 3 | kashan
# Processing Record 23 of Set 3 | dandong
# Processing Record 24 of Set 3 | sobolevo
# Processing Record 25 of Set 3 | ancud
# Processing Record 26 of Set 3 | cidreira
# Processing Record 27 of Set 3 | upernavik
# Processing Record 28 of Set 3 | iquique
# Processing Record 29 of Set 3 | zhigansk
# Processing Record 30 of Set 3 | grindavik
# Processing Record 31 of Set 3 | conakry
# Processing Record 32 of Set 3 | saint george
# Processing Record 33 of Set 3 | pevek
# Processing Record 34 of Set 3 | utiroa
# City not found. Skipping...
# Processing Record 35 of Set 3 | qaanaaq
# Processing Record 36 of Set 3 | prokuplje
# Processing Record 37 of Set 3 | aklavik
# Processing Record 38 of Set 3 | pinawa
# Processing Record 39 of Set 3 | gat
# Processing Record 40 of Set 3 | bobrovka
# Processing Record 41 of Set 3 | kharitonovo
# Processing Record 42 of Set 3 | chokurdakh
# Processing Record 43 of Set 3 | sioux lookout
# Processing Record 44 of Set 3 | svetlogorsk
# Processing Record 45 of Set 3 | arman
# Processing Record 46 of Set 3 | dunedin
# Processing Record 47 of Set 3 | broome
# Processing Record 48 of Set 3 | lorengau
# Processing Record 49 of Set 3 | narsaq
# Processing Record 50 of Set 3 | hue
# Processing Record 1 of Set 4 | chapais
# Processing Record 2 of Set 4 | proletarsk
# Processing Record 3 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 4 | karratha
# Processing Record 5 of Set 4 | manjo
# Processing Record 6 of Set 4 | rantepao
# Processing Record 7 of Set 4 | georgetown
# Processing Record 8 of Set 4 | atuona
# Processing Record 9 of Set 4 | yellowknife
# Processing Record 10 of Set 4 | tura
# Processing Record 11 of Set 4 | atar
# Processing Record 12 of Set 4 | hasaki
# Processing Record 13 of Set 4 | soria
# Processing Record 14 of Set 4 | te anau
# Processing Record 15 of Set 4 | kieta
# Processing Record 16 of Set 4 | lindi
# Processing Record 17 of Set 4 | jutai
# Processing Record 18 of Set 4 | bandarbeyla
# Processing Record 19 of Set 4 | ahuimanu
# Processing Record 20 of Set 4 | camacha
# Processing Record 21 of Set 4 | ponnani
# Processing Record 22 of Set 4 | souillac
# Processing Record 23 of Set 4 | foldeak
# Processing Record 24 of Set 4 | muli
# Processing Record 25 of Set 4 | urdzhar
# City not found. Skipping...
# Processing Record 26 of Set 4 | shubarshi
# Processing Record 27 of Set 4 | pelym
# Processing Record 28 of Set 4 | hobart
# Processing Record 29 of Set 4 | cockburn town
# Processing Record 30 of Set 4 | mount gambier
# Processing Record 31 of Set 4 | miyako
# Processing Record 32 of Set 4 | enid
# Processing Record 33 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 34 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 35 of Set 4 | kununurra
# Processing Record 36 of Set 4 | loandjili
# Processing Record 37 of Set 4 | vardo
# Processing Record 38 of Set 4 | ambilobe
# Processing Record 39 of Set 4 | kajaani
# Processing Record 40 of Set 4 | puerto ayora
# Processing Record 41 of Set 4 | nizhniy tsasuchey
# Processing Record 42 of Set 4 | saldanha
# Processing Record 43 of Set 4 | labuhan
# Processing Record 44 of Set 4 | coahuayana
# Processing Record 45 of Set 4 | airai
# Processing Record 46 of Set 4 | severo-kurilsk
# Processing Record 47 of Set 4 | jati
# Processing Record 48 of Set 4 | klaksvik
# Processing Record 49 of Set 4 | yatou
# Processing Record 50 of Set 4 | bambous virieux
# Processing Record 1 of Set 5 | caravelas
# Processing Record 2 of Set 5 | ostrovnoy
# Processing Record 3 of Set 5 | kavaratti
# Processing Record 4 of Set 5 | komsomolskiy
# Processing Record 5 of Set 5 | kichera
# Processing Record 6 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 7 of Set 5 | kumluca
# Processing Record 8 of Set 5 | hereford
# Processing Record 9 of Set 5 | bloomfield
# Processing Record 10 of Set 5 | verkhnevilyuysk
# Processing Record 11 of Set 5 | belmonte
# Processing Record 12 of Set 5 | gulshat
# City not found. Skipping...
# Processing Record 13 of Set 5 | alta floresta
# Processing Record 14 of Set 5 | maromitsa
# Processing Record 15 of Set 5 | richards bay
# Processing Record 16 of Set 5 | padang
# Processing Record 17 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 18 of Set 5 | darhan
# Processing Record 19 of Set 5 | oktyabrskoye
# Processing Record 20 of Set 5 | sinnamary
# Processing Record 21 of Set 5 | xining
# Processing Record 22 of Set 5 | mindelo
# Processing Record 23 of Set 5 | yar-sale
# Processing Record 24 of Set 5 | manama
# Processing Record 25 of Set 5 | port-gentil
# Processing Record 26 of Set 5 | lebu
# Processing Record 27 of Set 5 | bac lieu
# Processing Record 28 of Set 5 | norden
# Processing Record 29 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 5 | ribeira grande
# Processing Record 31 of Set 5 | chau doc
# Processing Record 32 of Set 5 | zunilito
# Processing Record 33 of Set 5 | san andres
# Processing Record 34 of Set 5 | krasnoselkup
# Processing Record 35 of Set 5 | bubaque
# Processing Record 36 of Set 5 | lasa
# Processing Record 37 of Set 5 | cheyenne
# Processing Record 38 of Set 5 | kavieng
# Processing Record 39 of Set 5 | akdepe
# Processing Record 40 of Set 5 | chuy
# Processing Record 41 of Set 5 | nicoya
# Processing Record 42 of Set 5 | spisske podhradie
# Processing Record 43 of Set 5 | norman wells
# Processing Record 44 of Set 5 | jiaocheng
# Processing Record 45 of Set 5 | kirkuk
# Processing Record 46 of Set 5 | nikolskoye
# Processing Record 47 of Set 5 | vostok
# Processing Record 48 of Set 5 | portland
# Processing Record 49 of Set 5 | pimentel
# Processing Record 50 of Set 5 | kruisfontein
# Processing Record 1 of Set 6 | beboto
# Processing Record 2 of Set 6 | odoyev
# Processing Record 3 of Set 6 | medellin
# Processing Record 4 of Set 6 | tezu
# Processing Record 5 of Set 6 | meulaboh
# Processing Record 6 of Set 6 | noumea
# Processing Record 7 of Set 6 | kalaiya
# Processing Record 8 of Set 6 | namibe
# Processing Record 9 of Set 6 | dujuma
# City not found. Skipping...
# Processing Record 10 of Set 6 | morrope
# Processing Record 11 of Set 6 | beringovskiy
# Processing Record 12 of Set 6 | antofagasta
# Processing Record 13 of Set 6 | trapani
# Processing Record 14 of Set 6 | leh
# Processing Record 15 of Set 6 | novyy urengoy
# Processing Record 16 of Set 6 | gamba
# Processing Record 17 of Set 6 | wright
# Processing Record 18 of Set 6 | katsiveli
# City not found. Skipping...
# Processing Record 19 of Set 6 | portmore
# Processing Record 20 of Set 6 | dano
# Processing Record 21 of Set 6 | port hedland
# Processing Record 22 of Set 6 | sao filipe
# Processing Record 23 of Set 6 | kirovskiy
# Processing Record 24 of Set 6 | vao
# Processing Record 25 of Set 6 | resistencia
# Processing Record 26 of Set 6 | nanortalik
# Processing Record 27 of Set 6 | kandalaksha
# Processing Record 28 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 29 of Set 6 | mount isa
# Processing Record 30 of Set 6 | polunochnoye
# Processing Record 31 of Set 6 | vila franca do campo
# Processing Record 32 of Set 6 | dawlatabad
# Processing Record 33 of Set 6 | azuaga
# Processing Record 34 of Set 6 | portobelo
# Processing Record 35 of Set 6 | mandalgovi
# Processing Record 36 of Set 6 | hithadhoo
# Processing Record 37 of Set 6 | biltine
# Processing Record 38 of Set 6 | terney
# Processing Record 39 of Set 6 | laplace
# Processing Record 40 of Set 6 | coihaique
# Processing Record 41 of Set 6 | jujuy
# City not found. Skipping...
# Processing Record 42 of Set 6 | tyukalinsk
# Processing Record 43 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 6 | naze
# Processing Record 45 of Set 6 | orotukan
# Processing Record 46 of Set 6 | fairbanks
# Processing Record 47 of Set 6 | karatuzskoye
# Processing Record 48 of Set 6 | pitimbu
# Processing Record 49 of Set 6 | capao bonito
# Processing Record 50 of Set 6 | yenagoa
# Processing Record 1 of Set 7 | khatanga
# Processing Record 2 of Set 7 | nelson bay
# Processing Record 3 of Set 7 | port elizabeth
# Processing Record 4 of Set 7 | cayenne
# Processing Record 5 of Set 7 | brahmapuri
# City not found. Skipping...
# Processing Record 6 of Set 7 | ketchenery
# City not found. Skipping...
# Processing Record 7 of Set 7 | talnakh
# Processing Record 8 of Set 7 | atzompa
# Processing Record 9 of Set 7 | samalaeulu
# City not found. Skipping...
# Processing Record 10 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 11 of Set 7 | fort nelson
# Processing Record 12 of Set 7 | zyryanka
# Processing Record 13 of Set 7 | kenai
# Processing Record 14 of Set 7 | kidderminster
# Processing Record 15 of Set 7 | nisia floresta
# Processing Record 16 of Set 7 | la union
# Processing Record 17 of Set 7 | rio grande
# Processing Record 18 of Set 7 | halalo
# City not found. Skipping...
# Processing Record 19 of Set 7 | tilichiki
# Processing Record 20 of Set 7 | greeneville
# Processing Record 21 of Set 7 | talaya
# Processing Record 22 of Set 7 | pyu
# Processing Record 23 of Set 7 | zaysan
# Processing Record 24 of Set 7 | san vicente
# Processing Record 25 of Set 7 | touros
# Processing Record 26 of Set 7 | chara
# Processing Record 27 of Set 7 | vila velha
# Processing Record 28 of Set 7 | lata
# Processing Record 29 of Set 7 | sur
# Processing Record 30 of Set 7 | nishihara
# Processing Record 31 of Set 7 | whitehorse
# Processing Record 32 of Set 7 | palmer
# Processing Record 33 of Set 7 | nouadhibou
# Processing Record 34 of Set 7 | puerto guzman
# Processing Record 35 of Set 7 | inirida
# Processing Record 36 of Set 7 | pisco
# Processing Record 37 of Set 7 | tasiilaq
# Processing Record 38 of Set 7 | juifang
# City not found. Skipping...
# Processing Record 39 of Set 7 | chicama
# Processing Record 40 of Set 7 | tapaua
# City not found. Skipping...
# Processing Record 41 of Set 7 | suratgarh
# Processing Record 42 of Set 7 | petropavlovsk-kamchatskiy
# Processing Record 43 of Set 7 | quelimane
# Processing Record 44 of Set 7 | cooma
# Processing Record 45 of Set 7 | yanan
# City not found. Skipping...
# Processing Record 46 of Set 7 | port-cartier
# Processing Record 47 of Set 7 | pangody
# Processing Record 48 of Set 7 | novoagansk
# Processing Record 49 of Set 7 | wagga wagga
# Processing Record 50 of Set 7 | launceston
# Processing Record 1 of Set 8 | nome
# Processing Record 2 of Set 8 | buarcos
# Processing Record 3 of Set 8 | olafsvik
# Processing Record 4 of Set 8 | wembley
# Processing Record 5 of Set 8 | hirado
# Processing Record 6 of Set 8 | aojiang
# Processing Record 7 of Set 8 | natal
# Processing Record 8 of Set 8 | erzin
# Processing Record 9 of Set 8 | don benito
# Processing Record 10 of Set 8 | beni
# Processing Record 11 of Set 8 | la ronge
# Processing Record 12 of Set 8 | port hardy
# Processing Record 13 of Set 8 | songjianghe
# Processing Record 14 of Set 8 | la asuncion
# Processing Record 15 of Set 8 | constantine
# Processing Record 16 of Set 8 | koster
# Processing Record 17 of Set 8 | kokopo
# Processing Record 18 of Set 8 | bilibino
# Processing Record 19 of Set 8 | margate
# Processing Record 20 of Set 8 | narasannapeta
# Processing Record 21 of Set 8 | termoli
# Processing Record 22 of Set 8 | maniitsoq
# Processing Record 23 of Set 8 | sao gabriel da cachoeira
# Processing Record 24 of Set 8 | hirara
# Processing Record 25 of Set 8 | novyy urgal
# Processing Record 26 of Set 8 | castro
# Processing Record 27 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 28 of Set 8 | srednekolymsk
# Processing Record 29 of Set 8 | goya
# Processing Record 30 of Set 8 | prince rupert
# Processing Record 31 of Set 8 | palkino
# Processing Record 32 of Set 8 | blind river
# Processing Record 33 of Set 8 | ongandjera
# Processing Record 34 of Set 8 | lagoa
# Processing Record 35 of Set 8 | batagay-alyta
# Processing Record 36 of Set 8 | phan thiet
# Processing Record 37 of Set 8 | geraldton
# Processing Record 38 of Set 8 | shalya
# Processing Record 39 of Set 8 | solnechnyy
# Processing Record 40 of Set 8 | muscatine
# Processing Record 41 of Set 8 | teguise
# Processing Record 42 of Set 8 | ketchikan
# Processing Record 43 of Set 8 | kismayo
# Processing Record 44 of Set 8 | burgeo
# Processing Record 45 of Set 8 | okhotsk
# Processing Record 46 of Set 8 | mazyr
# Processing Record 47 of Set 8 | husavik
# Processing Record 48 of Set 8 | kilindoni
# Processing Record 49 of Set 8 | anyang
# Processing Record 50 of Set 8 | bonavista
# Processing Record 1 of Set 9 | coos bay
# Processing Record 2 of Set 9 | paamiut
# Processing Record 3 of Set 9 | sorland
# Processing Record 4 of Set 9 | kasane
# Processing Record 5 of Set 9 | rawannawi
# City not found. Skipping...
# Processing Record 6 of Set 9 | agadez
# Processing Record 7 of Set 9 | mecca
# Processing Record 8 of Set 9 | wasilla
# Processing Record 9 of Set 9 | leningradskiy
# Processing Record 10 of Set 9 | mana
# Processing Record 11 of Set 9 | albina
# Processing Record 12 of Set 9 | yokadouma
# Processing Record 13 of Set 9 | thompson
# Processing Record 14 of Set 9 | qandahar
# City not found. Skipping...
# Processing Record 15 of Set 9 | normandin
# Processing Record 16 of Set 9 | namatanai
# Processing Record 17 of Set 9 | warsaw
# Processing Record 18 of Set 9 | ponta do sol
# Processing Record 19 of Set 9 | ban nahin
# Processing Record 20 of Set 9 | esperance
# Processing Record 21 of Set 9 | awallan
# Processing Record 22 of Set 9 | arlit
# Processing Record 23 of Set 9 | nago
# Processing Record 24 of Set 9 | san ramon
# Processing Record 25 of Set 9 | nalvo
# Processing Record 26 of Set 9 | nagyatad
# Processing Record 27 of Set 9 | xichang
# Processing Record 28 of Set 9 | xuddur
# Processing Record 29 of Set 9 | maldonado
# Processing Record 30 of Set 9 | vaijapur
# Processing Record 31 of Set 9 | alice springs
# Processing Record 32 of Set 9 | manono
# Processing Record 33 of Set 9 | korla
# Processing Record 34 of Set 9 | eureka
# Processing Record 35 of Set 9 | iskateley
# Processing Record 36 of Set 9 | yumen
# Processing Record 37 of Set 9 | pacific grove
# Processing Record 38 of Set 9 | isangel
# Processing Record 39 of Set 9 | makhinjauri
# Processing Record 40 of Set 9 | gustrow
# Processing Record 41 of Set 9 | dzilam gonzalez
# Processing Record 42 of Set 9 | samarinda
# Processing Record 43 of Set 9 | sechura
# Processing Record 44 of Set 9 | tuatapere
# Processing Record 45 of Set 9 | xinan
# Processing Record 46 of Set 9 | kloulklubed
# Processing Record 47 of Set 9 | bengkulu
# Processing Record 48 of Set 9 | camargo
# Processing Record 49 of Set 9 | elko
# Processing Record 50 of Set 9 | ambositra
# Processing Record 1 of Set 10 | atbasar
# Processing Record 2 of Set 10 | laguna
# Processing Record 3 of Set 10 | kjopsvik
# Processing Record 4 of Set 10 | sedelnikovo
# City not found. Skipping...
# Processing Record 5 of Set 10 | asekeyevo
# Processing Record 6 of Set 10 | japura
# Processing Record 7 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 8 of Set 10 | mizpe ramon
# City not found. Skipping...
# Processing Record 9 of Set 10 | saint-augustin
# Processing Record 10 of Set 10 | wonopringgo
# Processing Record 11 of Set 10 | iracoubo
# Processing Record 12 of Set 10 | hovd
# Processing Record 13 of Set 10 | ladario
# Processing Record 14 of Set 10 | fatikchhari
# City not found. Skipping...
# Processing Record 15 of Set 10 | togur
# Processing Record 16 of Set 10 | sitka
# Processing Record 17 of Set 10 | washington
# Processing Record 18 of Set 10 | guerrero negro
# Processing Record 19 of Set 10 | tiarei
# Processing Record 20 of Set 10 | sambava
# Processing Record 21 of Set 10 | ugoofaaru
# Processing Record 22 of Set 10 | wynyard
# Processing Record 23 of Set 10 | dukat
# Processing Record 24 of Set 10 | girne
# Processing Record 25 of Set 10 | half moon bay
# Processing Record 26 of Set 10 | iqaluit
# Processing Record 27 of Set 10 | gambiran
# Processing Record 28 of Set 10 | farafangana
# Processing Record 29 of Set 10 | la reforma
# Processing Record 30 of Set 10 | breytovo
# Processing Record 31 of Set 10 | bathsheba
# Processing Record 32 of Set 10 | bako
# Processing Record 33 of Set 10 | alyangula
# Processing Record 34 of Set 10 | sao marcos
# Processing Record 35 of Set 10 | ewa beach
# Processing Record 36 of Set 10 | kulim
# Processing Record 37 of Set 10 | weihe
# Processing Record 38 of Set 10 | san patricio
# Processing Record 39 of Set 10 | bafq
# Processing Record 40 of Set 10 | fortuna
# Processing Record 41 of Set 10 | azimur
# City not found. Skipping...
# Processing Record 42 of Set 10 | cabedelo
# Processing Record 43 of Set 10 | roma
# Processing Record 44 of Set 10 | lamu
# Processing Record 45 of Set 10 | paslek
# Processing Record 46 of Set 10 | tessalit
# Processing Record 47 of Set 10 | ekhabi
# Processing Record 48 of Set 10 | bitung
# Processing Record 49 of Set 10 | zhob
# Processing Record 50 of Set 10 | filadelfia
# Processing Record 1 of Set 11 | salinopolis
# Processing Record 2 of Set 11 | tamandare
# Processing Record 3 of Set 11 | pohorelice
# Processing Record 4 of Set 11 | warner robins
# Processing Record 5 of Set 11 | sabha
# Processing Record 6 of Set 11 | san buenaventura
# Processing Record 7 of Set 11 | axim
# Processing Record 8 of Set 11 | deputatskiy
# Processing Record 9 of Set 11 | talara
# Processing Record 10 of Set 11 | kuche
# City not found. Skipping...
# Processing Record 11 of Set 11 | poum
# Processing Record 12 of Set 11 | tateyama
# Processing Record 13 of Set 11 | abeche
# Processing Record 14 of Set 11 | brigantine
# Processing Record 15 of Set 11 | hay river
# Processing Record 16 of Set 11 | shaunavon
# Processing Record 17 of Set 11 | talcahuano
# Processing Record 18 of Set 11 | wawa
# Processing Record 19 of Set 11 | ulaangom
# Processing Record 20 of Set 11 | riyadh
# Processing Record 21 of Set 11 | kudamatsu
# Processing Record 22 of Set 11 | lolua
# City not found. Skipping...
# Processing Record 23 of Set 11 | kamina
# Processing Record 24 of Set 11 | taoudenni
# Processing Record 25 of Set 11 | banda aceh
# Processing Record 26 of Set 11 | parauna
# Processing Record 27 of Set 11 | tucuman
# Processing Record 28 of Set 11 | murgab
# Processing Record 29 of Set 11 | skjervoy
# Processing Record 30 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 31 of Set 11 | adeje
# Processing Record 32 of Set 11 | modra
# Processing Record 33 of Set 11 | mendoza
# Processing Record 34 of Set 11 | ambulu
# Processing Record 35 of Set 11 | mackenzie
# Processing Record 36 of Set 11 | kamenka
# Processing Record 37 of Set 11 | san fernando
# Processing Record 38 of Set 11 | comodoro rivadavia
# Processing Record 39 of Set 11 | dunmore town
# Processing Record 40 of Set 11 | batemans bay
# Processing Record 41 of Set 11 | makung
# City not found. Skipping...
# Processing Record 42 of Set 11 | constitucion
# Processing Record 43 of Set 11 | birin
# Processing Record 44 of Set 11 | manmad
# Processing Record 45 of Set 11 | fort smith
# Processing Record 46 of Set 11 | port lincoln
# Processing Record 47 of Set 11 | kudahuvadhoo
# Processing Record 48 of Set 11 | panjwin
# City not found. Skipping...
# Processing Record 49 of Set 11 | satitoa
# City not found. Skipping...
# Processing Record 50 of Set 11 | asau
# Processing Record 1 of Set 12 | bada
# Processing Record 2 of Set 12 | longlac
# City not found. Skipping...
# Processing Record 3 of Set 12 | temaraia
# City not found. Skipping...
# Processing Record 4 of Set 12 | lapithos
# Processing Record 5 of Set 12 | acapulco
# Processing Record 6 of Set 12 | karari
# Processing Record 7 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 8 of Set 12 | adrar
# Processing Record 9 of Set 12 | avera
# Processing Record 10 of Set 12 | kalmunai
# Processing Record 11 of Set 12 | tagusao
# Processing Record 12 of Set 12 | rawson
# Processing Record 13 of Set 12 | nadym
# Processing Record 14 of Set 12 | sukpak
# Processing Record 15 of Set 12 | le moule
# Processing Record 16 of Set 12 | fallon
# Processing Record 17 of Set 12 | bacuit
# City not found. Skipping...
# Processing Record 18 of Set 12 | gornyak
# Processing Record 19 of Set 12 | kidal
# Processing Record 20 of Set 12 | qaqortoq
# Processing Record 21 of Set 12 | gangotri
# City not found. Skipping...
# Processing Record 22 of Set 12 | apricena
# Processing Record 23 of Set 12 | athabasca
# Processing Record 24 of Set 12 | aswan
# Processing Record 25 of Set 12 | puerto el triunfo
# Processing Record 26 of Set 12 | strzelin
# Processing Record 27 of Set 12 | manaure
# Processing Record 28 of Set 12 | buchanan
# Processing Record 29 of Set 12 | tatarsk
# Processing Record 30 of Set 12 | kommunisticheskiy
# Processing Record 31 of Set 12 | meadow lake
# Processing Record 32 of Set 12 | elat
# Processing Record 33 of Set 12 | kungurtug
# Processing Record 34 of Set 12 | barroso
# Processing Record 35 of Set 12 | duz
# City not found. Skipping...
# Processing Record 36 of Set 12 | lavrentiya
# Processing Record 37 of Set 12 | ta khmau
# Processing Record 38 of Set 12 | alofi
# Processing Record 39 of Set 12 | uhlove
# Processing Record 40 of Set 12 | belen
# Processing Record 41 of Set 12 | sung noen
# Processing Record 42 of Set 12 | vaitupu
# City not found. Skipping...
# Processing Record 43 of Set 12 | mnogovershinnyy
# Processing Record 44 of Set 12 | muisne
# Processing Record 45 of Set 12 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 12 | tzaneen
# Processing Record 47 of Set 12 | gobabis
# Processing Record 48 of Set 12 | kuhestan
# City not found. Skipping...
# Processing Record 49 of Set 12 | henties bay
# Processing Record 50 of Set 12 | tres arroyos
# Processing Record 1 of Set 13 | sudzha
# Processing Record 2 of Set 13 | valuyki
# Processing Record 3 of Set 13 | montague
# Processing Record 4 of Set 13 | pahrump
# Processing Record 5 of Set 13 | altamont
# Processing Record 6 of Set 13 | risch
# Processing Record 7 of Set 13 | kupino
# Processing Record 8 of Set 13 | makat
# Processing Record 9 of Set 13 | lubango
# Processing Record 10 of Set 13 | sataua
# City not found. Skipping...
# Processing Record 11 of Set 13 | tommot
# Processing Record 12 of Set 13 | hami
# Processing Record 13 of Set 13 | wulanhaote
# City not found. Skipping...
# Processing Record 14 of Set 13 | dolbeau
# City not found. Skipping...
# Processing Record 15 of Set 13 | minot
# Processing Record 16 of Set 13 | rocha
# Processing Record 17 of Set 13 | tabas
# Processing Record 18 of Set 13 | umm lajj
# Processing Record 19 of Set 13 | san clemente
# Processing Record 20 of Set 13 | baykit
# Processing Record 21 of Set 13 | amarillo
# Processing Record 22 of Set 13 | cuxhaven
# Processing Record 23 of Set 13 | alotau
# City not found. Skipping...
# Processing Record 24 of Set 13 | tulle
# Processing Record 25 of Set 13 | barcelos
# Processing Record 26 of Set 13 | marshall
# Processing Record 27 of Set 13 | lagos
# Processing Record 28 of Set 13 | srandakan
# Processing Record 29 of Set 13 | almaznyy
# Processing Record 30 of Set 13 | gazli
# Processing Record 31 of Set 13 | kilmez
# City not found. Skipping...
# Processing Record 32 of Set 13 | praia da vitoria
# Processing Record 33 of Set 13 | staryy nadym
# Processing Record 34 of Set 13 | watrous
# Processing Record 35 of Set 13 | zemio
# Processing Record 36 of Set 13 | vestmanna
# Processing Record 37 of Set 13 | wakkanai
# Processing Record 38 of Set 13 | sangar
# Processing Record 39 of Set 13 | palabuhanratu
# City not found. Skipping...
# Processing Record 40 of Set 13 | barroualie
# City not found. Skipping...
# Processing Record 41 of Set 13 | afmadu
# City not found. Skipping...
# Processing Record 42 of Set 13 | defiance
# Processing Record 43 of Set 13 | quchan
# Processing Record 44 of Set 13 | qixingtai
# Processing Record 45 of Set 13 | port blair
# Processing Record 46 of Set 13 | scarborough
# Processing Record 47 of Set 13 | sorvag
# City not found. Skipping...
# Processing Record 48 of Set 13 | port macquarie
# Processing Record 49 of Set 13 | myitkyina
# Processing Record 50 of Set 13 | lanxi
# Processing Record 1 of Set 14 | houma
# Processing Record 2 of Set 14 | lazaro cardenas
# Processing Record 3 of Set 14 | charyshskoye
# Processing Record 4 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 5 of Set 14 | qitaihe
# Processing Record 6 of Set 14 | waingapu
# Processing Record 7 of Set 14 | cozumel
# Processing Record 8 of Set 14 | jatai
# Processing Record 9 of Set 14 | balagansk
# Processing Record 10 of Set 14 | celestun
# Processing Record 11 of Set 14 | shingu
# Processing Record 12 of Set 14 | amahai
# Processing Record 13 of Set 14 | buin
# Processing Record 14 of Set 14 | mokobeng
# Processing Record 15 of Set 14 | buta
# Processing Record 16 of Set 14 | beian
# Processing Record 17 of Set 14 | hervey bay
# Processing Record 18 of Set 14 | melfort
# Processing Record 19 of Set 14 | melbu
# Processing Record 20 of Set 14 | faya
# Processing Record 21 of Set 14 | villiers
# Processing Record 22 of Set 14 | rumoi
# Processing Record 23 of Set 14 | havoysund
# Processing Record 24 of Set 14 | tumannyy
# City not found. Skipping...
# Processing Record 25 of Set 14 | hobyo
# Processing Record 26 of Set 14 | sola
# Processing Record 27 of Set 14 | mansfield
# Processing Record 28 of Set 14 | inongo
# Processing Record 29 of Set 14 | shiloh
# Processing Record 30 of Set 14 | campoverde
# Processing Record 31 of Set 14 | kyzyl-suu
# Processing Record 32 of Set 14 | ouahigouya
# Processing Record 33 of Set 14 | tahara
# Processing Record 34 of Set 14 | ust-nera
# Processing Record 35 of Set 14 | gunjur
# Processing Record 36 of Set 14 | arona
# Processing Record 37 of Set 14 | romny
# Processing Record 38 of Set 14 | honiara
# Processing Record 39 of Set 14 | uthal
# Processing Record 40 of Set 14 | sarkand
# Processing Record 41 of Set 14 | nsoko
# Processing Record 42 of Set 14 | lagdo
# Processing Record 43 of Set 14 | washim
# Processing Record 44 of Set 14 | nipawin
# Processing Record 45 of Set 14 | ilhabela
# Processing Record 46 of Set 14 | marawi
# Processing Record 47 of Set 14 | khandbari
# Processing Record 48 of Set 14 | ushtobe
# Processing Record 49 of Set 14 | tarkwa
# Processing Record 50 of Set 14 | port augusta
# Processing Record 1 of Set 15 | el wasta
# City not found. Skipping...
# Processing Record 2 of Set 15 | luganville
# Processing Record 3 of Set 15 | grootfontein
# Processing Record 4 of Set 15 | soyo
# Processing Record 5 of Set 15 | bugene
# Processing Record 6 of Set 15 | mama
# Processing Record 7 of Set 15 | lyaskelya
# Processing Record 8 of Set 15 | ventspils
# Processing Record 9 of Set 15 | povenets
# Processing Record 10 of Set 15 | beihai
# Processing Record 11 of Set 15 | ibra
# Processing Record 12 of Set 15 | tourlaville
# Processing Record 13 of Set 15 | koumac
# Processing Record 14 of Set 15 | bonga
# Processing Record 15 of Set 15 | viedma
# Processing Record 16 of Set 15 | new port richey
# Processing Record 17 of Set 15 | saint-honore
# Processing Record 18 of Set 15 | biak
# Processing Record 19 of Set 15 | putina
# Processing Record 20 of Set 15 | san quintin
# Processing Record 21 of Set 15 | burica
# City not found. Skipping...
# Processing Record 22 of Set 15 | strezhevoy
# Processing Record 23 of Set 15 | chillicothe
# Processing Record 24 of Set 15 | suraabad
# Processing Record 25 of Set 15 | bukachacha
# Processing Record 26 of Set 15 | poopo
# Processing Record 27 of Set 15 | gornopravdinsk
# Processing Record 28 of Set 15 | bairiki
# Processing Record 29 of Set 15 | don sak
# Processing Record 30 of Set 15 | saint anthony
# Processing Record 31 of Set 15 | belaya gora
# Processing Record 32 of Set 15 | suntar
# Processing Record 33 of Set 15 | kingisepp
# Processing Record 34 of Set 15 | emerald
# Processing Record 35 of Set 15 | joensuu
# Processing Record 36 of Set 15 | haimen
# Processing Record 37 of Set 15 | moron
# Processing Record 38 of Set 15 | mayumba
# Processing Record 39 of Set 15 | nantucket
# Processing Record 40 of Set 15 | naarden
# Processing Record 41 of Set 15 | sosva
# Processing Record 42 of Set 15 | grand centre
# City not found. Skipping...
# Processing Record 43 of Set 15 | wajir
# Processing Record 44 of Set 15 | victor harbor
# Processing Record 45 of Set 15 | prado
# Processing Record 46 of Set 15 | maceio
# Processing Record 47 of Set 15 | san policarpo
# Processing Record 48 of Set 15 | cap malheureux
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data_df = pd.DataFrameramerame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0          Aden      YE  12.7794   45.0367     79.18        66           5
# 1  Punta Arenas      CL -53.1500  -70.9167     41.11        81          20
# 2    Bredasdorp      ZA -34.5322   20.0403     54.72        82          98
# 3      Manicore      BR  -5.8092  -61.3003     72.32       100         100
# 4        Bethel      US  41.3712  -73.4140     31.66        69         100
# 5          Hilo      US  19.7297 -155.0900     71.33        85           0
# 6       Rikitea      PF -23.1203 -134.9692     80.11        72          55
# 7          Teya      RU  60.3778   92.6267     10.49        74          95
# 8         Cabra      ES  37.4725   -4.4421     53.19        88         100
# 9  Longyearbyen      SJ  78.2186   15.6401     30.83        94         100
#
#    Wind Speed Current Description
# 0       14.54           clear sky
# 1       19.57          few clouds
# 2        9.22     overcast clouds
# 3        1.88          light rain
# 4        4.61     overcast clouds
# 5        1.01           clear sky
# 6       14.36       broken clouds
# 7        2.75     overcast clouds
# 8        1.01          light rain
# 9       18.81                snow

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
